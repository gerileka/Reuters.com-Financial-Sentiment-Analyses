# %%
from Content_function import get_data
import pandas as pd

# %%
# If you want a fresh batch of data please run the following function:
df = get_data(10) # This will be saved in the folder data in an xlsx file

# If you want a pre downloaded batch of data, please use the following:
df = pd.read_excel('../data/content.xlsx')
# Out:
# https://www.reuters.com/news/archive/bank-news?view=page&page=1&pageSize=10
# https://www.reuters.com/news/archive/bank-news?view=page&page=2&pageSize=10
# https://www.reuters.com/news/archive/bank-news?view=page&page=3&pageSize=10
# https://www.reuters.com/news/archive/bank-news?view=page&page=4&pageSize=10
# https://www.reuters.com/news/archive/bank-news?view=page&page=5&pageSize=10
# https://www.reuters.com/news/archive/bank-news?view=page&page=6&pageSize=10
# https://www.reuters.com/news/archive/bank-news?view=page&page=7&pageSize=10
# https://www.reuters.com/news/archive/bank-news?view=page&page=8&pageSize=10
# https://www.reuters.com/news/archive/bank-news?view=page&page=9&pageSize=10
# https://www.reuters.com/news/archive/bank-news?view=page&page=10&pageSize=10

# %%
df
# Out:
#                                                 Title           Date  \
# 0   Japan's service sector slump eases as pandemic...  July 3, 2020
# 1   Breakingviews - Oil majors’ Atlantic divide sh...  July 2, 2020
# 2   European stocks slide as surge in virus cases ...  July 3, 2020
# 3   EU lawmakers reject banking watchdog candidate...  July 3, 2020
# 4   Egg salad and a basketball star provide one Ca...  July 2, 2020
# 5   Fed balance sheet shrinks further, and still n...  July 2, 2020
# 6    Deutsche Bank weighs support for Wirecard's bank  July 2, 2020
# 7   China's services sector grows at fastest pace ...  July 3, 2020
# 8   BofA's U.S. staff to start returning to office...  July 2, 2020
# 9   Deutsche Bank eyes payment systems, including ...  July 3, 2020
# 10  No politics, please! Hong Kong finance profess...  July 2, 2020
# 11  Argentine creditors build 'Pac-Man' defences a...  July 3, 2020
# 12  Exclusive: Indonesia considers putting banking...  July 2, 2020
# ...
